# %% [markdown]
# # **Visualizing Results**

# %% [markdown]
# We first need to import all the libraries we'll use:

# %%
#LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We start our research by first reading the CSV file with training data and adding a label column. The training set contains 4000 examples: 2011 belong to class 0 and 1996 to class 1. Each example has 64 attributes (corresponding to 64 columns in the CSV file).

# %%
df = pd.read_csv('trainData/42_train.csv', header=None)
df['label'] = 0
df.loc[2000:, 'label'] = 1

print(df.head())
print(df.tail())
# Out:
#           0         1          2          3         4          5         6  \
# 0  100.9114  129.3137  131.35200  102.59200  57.18311 -11.055980 -38.61711
# 1  125.8028  186.2725  150.18880   74.78534  56.73462  26.393350  11.61433
# 2  158.0945  185.8240   93.22995   45.40892   0.00000  26.169100 -38.61711
# 3  100.9114  186.0483   93.22995  102.59200  56.73462  26.393350 -38.61711
# 4  100.9114  155.7749  149.96460   45.40892   0.00000   8.677794  18.11751
#
#           7          8         9  ...         55        56        57  \
# 0  31.46103   98.97239  181.9335  ...   69.98405  19.68683  92.86066
# 1  30.78828  155.70700  181.4850  ...   74.46899  30.89921  35.67756
# 2 -25.72209  111.08170  131.2535  ...  102.72420  73.95473  35.67756
# 3  31.23678   98.97239  124.7504  ...   69.98405  38.07513  35.67756
# 4 -25.72209   98.97239  181.4850  ...   69.98405  23.94753  92.18793
#
#           58        59         60        61         62         63  label
# ...

# %% [markdown]
# We then need to do the same with test data. The test set contains 5000 unlabeled examples. Each example again has 64 attributes.

# %%
test_data = pd.read_csv('trainData/42_test.csv', header=None)

print(test_data.head())
print(test_data.tail())
# Out:
#          0         1          2          3         4          5          6   \
# 0  100.9114  129.3137   93.22995   45.40892   0.00000 -30.341270   8.699111
# 1  151.5913  173.7147   93.22995   89.80992  38.12207  -4.777054  -0.495036
# 2  157.4217  186.0483   93.22995  101.91930  56.73462   7.556558  17.893260
# 3  139.4819  130.4349  149.74030   60.43350  15.47308  26.169100  17.893260
# 4  100.9114  186.0483   93.22995   45.40892  24.44298  -5.449797 -38.617110
#
#          7          8         9   ...        54         55        56  \
# 0 -25.72209   98.97239  124.7504  ...  121.8108   69.98405  19.68683
# 1 -25.72209   98.97239  124.7504  ...  178.9939   69.98405  76.86994
# 2  30.78828  155.70700  139.7749  ...  133.9202  126.71870  76.19720
# 3  20.02440  148.30680  124.7504  ...  178.3212   70.43254  19.68683
# 4  17.33343  155.70700  124.7504  ...  178.5454   69.98405  58.93014
#
#          57         58         59         60        61         62         63
# ...

# %% [markdown]
# The last piece of preparation before we look into the data is splitting the training dataset into features $X$ and target variable $y$.

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

print(X.shape)
print(y.shape)
# Out:
# (4000, 64)
# (4000,)

# %% [markdown]
# ## Decision Tree Classifier

# %%
from classifiers import decision_tree_classifier
# Out:
# 5-fold CV AUCs: [0.909  0.8748 0.8958 0.8886 0.8874]
# Estimated AUC (mean ± std): 0.891128125 ± 0.011215999837007459
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       600
#            1       0.82      0.86      0.84       600
#
#     accuracy                           0.83      1200
#    macro avg       0.83      0.83      0.83      1200
# weighted avg       0.83      0.83      0.83      1200
#
# [1 1 0 0 1]
# Validation AUC: 0.9021958333333334
# Submission shape should be (50000,): (50000,)

# %% [markdown]
# ## Random Forest Classifier

# %%
from classifiers import random_forest
# Out:
# 5-fold CV AUCs: [0.9739 0.9674 0.9639 0.9717 0.9602]
# Estimated AUC (mean ± std): 0.9674206250000001 ± 0.005011024408741137
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92       600
#            1       0.93      0.89      0.91       600
#
#     accuracy                           0.91      1200
#    macro avg       0.91      0.91      0.91      1200
# weighted avg       0.91      0.91      0.91      1200
#
# [1 0 0 0 1]
# Validation AUC: 0.9712236111111111
# Submission shape should be (50000,): (50000,)
# Train AUC: 1.0
# Val AUC:  1.0
# Gap: 0.0
# Permutation test AUCs: [0.50455625 0.4849875  0.49388437 0.50534375 0.48618125]
# Permutation test mean AUC: 0.49499062499999996

# %% [markdown]
# ## Logistic Regression

# %%
from classifiers import logistic_regression
